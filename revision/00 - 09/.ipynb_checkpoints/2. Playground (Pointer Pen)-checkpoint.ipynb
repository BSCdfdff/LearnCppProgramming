// %% [markdown]
// ## Messing with
//
// + Array - how to define it
// + How to pass it as parameter
//
// ![Mindmapcpp-Pointers%20%282%29.png](attachment:Mindmapcpp-Pointers%20%282%29.png)

// %%
#include <iostream>
#include <climits>
#include <math.h>
#define INSERTION_OPERATOR operator<<
#define EXTRACTION_OPERATOR operator>>
#define ADDITION_OPERATOR operator+
using namespace std;

// %%
int x = 10;
int *p;
//Only a pointer can reference an address
p=&x;

// %%
cout<<p<<endl;
// Out:
// 0x7f50f57ec030

// %%
//Dereference to get the value
cout<<*p<<endl;
// Out:
// 10

// %%
//Its own address
cout<<&p<<endl;
// Out:
// 0x7f50f57ec028

// %%
//Initialisation and declations

int *z = new int[5]

// %%
int A[5] ={4,5};
int *pA=A;

// %%
cout<<pA[1]<<endl;
// Out:
// 5

// %%
//Pointer reference, not still creating pointer, no need for it, that is *v)
int w = 10;
int &v = w;

// %%
cout<<v<<endl;
// Out:
// 10
